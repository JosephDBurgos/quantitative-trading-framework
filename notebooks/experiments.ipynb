# %% [markdown]
# # Experiments Notebook
#
# This notebook is used for exploratory analysis and experimentation with different trading strategies and parameters. It allows for interactive testing and visualization of the strategies implemented in the project.

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Import custom strategy classes
from strategies.base import StrategyBase
from strategies.moving_average import MovingAverageStrategy
from strategies.rsi_reversion import RSIReversionStrategy
from backtest.engine import BacktestEngine
from backtest.metrics import compute_sharpe_ratio, compute_max_drawdown

# Set visualization style
sns.set(style='whitegrid')

# %% [markdown]
# ## Load Data
#
# In this section, we will load the historical data required for backtesting the strategies.

# %%
# Load historical data
# Example: data = pd.read_csv('data/historical_data.csv')
data = None  # Replace with actual data loading logic

# %% [markdown]
# ## Strategy Testing
#
# Here we will define functions to test different strategies and visualize their performance.

# %%
def test_strategy(strategy_class, data):
    strategy = strategy_class()
    backtest_engine = BacktestEngine(strategy)
    results = backtest_engine.run(data)
    return results

# Example usage
# results_ma = test_strategy(MovingAverageStrategy, data)
# results_rsi = test_strategy(RSIReversionStrategy, data)

# %% [markdown]
# ## Visualization
#
# This section will include functions to visualize the results of the backtests.

# %%
def plot_results(results):
    plt.figure(figsize=(12, 6))
    plt.plot(results['dates'], results['equity_curve'], label='Equity Curve')
    plt.title('Strategy Equity Curve')
    plt.xlabel('Date')
    plt.ylabel('Equity')
    plt.legend()
    plt.show()

# Example usage
# plot_results(results_ma)

# %% [markdown]
# ## Conclusion
#
# In this notebook, we will summarize our findings and insights from the experiments conducted.
